# %%
x=10
if x>5:
  print("x is greater than 5")
# Out:
# x is greater than 5

# %%
y = 3
if y % 2 == 0:
    print("y is even")
else:
    print("y is odd")
# Out:
# y is odd

# %%
name= str(input("ENTER YOUR NAME:"))
course=str(input("ENTER YOUR COURSE:"))
roll=int(input("ENTER YOUR ROLL NUMBER:"))
branch=str(input("ENTER YOUR BRANCH:"))
m1=int(input("ENTER YOUR MARKS IN SUBJECT 1:"))
m2=int(input("ENTER YOUR MARKS IN SUBJECT 2:"))
m3=int(input("ENTER YOUR MARKS IN SUBJECT 3:"))
m4=int(input("ENTER YOUR MARKS IN SUBJECT 4:"))
m5=int(input("ENTER YOUR MARKS IN SUBJECT 5:"))
percentage=float((m1+m2+m3+m4+m5)/5.0)
print("PERCENTAGE:",percentage)
if percentage>=80.00:
  print("YOU WILL BE A PART OF A0 BATCH")
elif percentage>=60.00 and percentage<80.00:
  print("YOU WILL BE A PART OF A1 BATCH")
elif percentage>=40.00 and percentage<60.00:
  print("YOU WILL BE A PART OF A2 BATCH")
else:
  print("YOU WILL BE A PART OF A3 BATCH")
# Out:
# ENTER YOUR NAME:ANSHITA JAIN
# ENTER YOUR COURSE:BTECH
# ENTER YOUR ROLL NUMBER:2501220100064
# ENTER YOUR BRANCH:CSE
# ENTER YOUR MARKS IN SUBJECT 1:80
# ENTER YOUR MARKS IN SUBJECT 2:90
# ENTER YOUR MARKS IN SUBJECT 3:75
# ENTER YOUR MARKS IN SUBJECT 4:95
# ENTER YOUR MARKS IN SUBJECT 5:100
# PERCENTAGE: 88.0
# YOU WILL BE A PART OF A0 BATCH

# %%
name = str(input("ENTER YOUR NAME: "))
course = str(input("ENTER YOUR COURSE: "))
roll = int(input("ENTER YOUR ROLL NUMBER: "))
branch = str(input("ENTER YOUR BRANCH: "))
sub = int(input("ENTER NUMBER OF SUBJECTS: "))
i=1
for i in range(1, sub + 1):
    m = int(input(f"ENTER YOUR MARKS IN SUBJECT {i}: "))

    if m >= 80:
        print("A+")
    elif m >= 70 and m < 80:
        print("A")
    elif m >= 60 and m < 70:
        print("B")
    elif m >= 50 and m < 60:
        print("C")
    else:
        print("D")
# Out:
# ENTER YOUR NAME: AKSHARA JAIN
# ENTER YOUR COURSE: BTECH
# ENTER YOUR ROLL NUMBER: 2501220100034
# ENTER YOUR BRANCH: CSE
# ENTER NUMBER OF SUBJECTS: 5
# ENTER YOUR MARKS IN SUBJECT 1: 86
# A+
# ENTER YOUR MARKS IN SUBJECT 2: 85
# A+
# ENTER YOUR MARKS IN SUBJECT 3: 74
# A
# ENTER YOUR MARKS IN SUBJECT 4: 53
# C
# ENTER YOUR MARKS IN SUBJECT 5: 98
# A+

# %%
l=[1,2,3,4,4,"SUDH","KUMAR",324,34.456,"ABC"]

# %%
l1_num=[]
l2_str=[]
for j in l:
  if type(j)==int or type(j)==float:
    l1_num.append(j)
  else:
    l2_str.append(j)

# %%
l2=[1,2,3,5.6,"REAR",True,"ABC"]
l2_num=[]
l3_str=[]
l3_bool=[]

# %%
for k in l:
    if type(k) == int or type(k) == float:
        if type(k) != bool:
            l2_num.append(k)
    elif type(k) == str:
        l3_str.append(k)
    elif type(k) == bool:
        l3_bool.append(k)

# %%
l2_num
# Out:
# [1, 2, 3, 4, 4, 324, 34.456]

# %%
l3_str
# Out:
# ['SUDH', 'KUMAR', 'ABC']

# %%
l3_bool
# Out:
# []
