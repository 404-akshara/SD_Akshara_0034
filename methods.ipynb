# %%
l=[1,2,3,4,45,5]
l1=[]
for i in l:
  l1.append(i**2)

# %%
l1
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
[i for i in l if i%2==0]
# Out:
# [2, 4]

# %%
l1=["sudha","skills","kumar","data science"]

# %%
[i.upper() for i in l1]
# Out:
# ['SUDHA', 'SKILLS', 'KUMAR', 'DATA SCIENCE']

# %%
list(i**2 for i in l)
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
d={"key1":1, "key2":2,"key3":3,"key4":4}

# %%
{k:v**2 for k, v in d.items()}
# Out:
# {'key1': 1, 'key2': 4, 'key3': 9, 'key4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3), ('key4', 4)])

# %%
{k: v for k, v in d.items() if v>1}
# Out:
# {'key2': 2, 'key3': 3, 'key4': 4}

# %%
def test():
  pass

# %%
def test1():
  print("this is my very very first function")

# %%
test1() + "sudh"
# Out:
# this is my very very first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_501/3118336650.py in <cell line: 0>()
# ----> 1 test1() + "sudh"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
  return "this is my very first return"

# %%
test2()
# Out:
# 'this is my very first return'

# %%
def test3():
  return "sudh",23,345.56,[1,2,3,3]

# %%
test3()
# Out:
# ('sudh', 23, 345.56, [1, 2, 3, 3])

# %%
a,b,c,d=test3()

# %%
a
# Out:
# 'sudh'

# %%
b
# Out:
# 23

# %%
c
# Out:
# 345.56

# %%
d
# Out:
# [1, 2, 3, 3]

# %%
a=1
b=4

# %%
def add():
  a=5+6/7
  return a

# %%
add()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
  d=a+b/c
  return d

# %%
test5(4,5,6.78)
# Out:
# 4.737463126843657

# %%
def test6(a,b):
  return a+b

# %%
test6(9,10)
# Out:
# 19

# %%
test6("sudh","kumar")
# Out:
# 'sudhkumar'

# %%
def test11(*args):
  return args + (1,2,3,4)

# %%
type(test11())
# Out:
# tuple

# %%
test11(1,2,3)
# Out:
# (1, 2, 3)

# %%
test11(1,2,3,"sudh","kumar",[1,2,3,4,4])
# Out:
# (1, 2, 3, 'sudh', 'kumar', [1, 2, 3, 4, 4], 1, 2, 3, 4)

# %%
def test12(*sudh):
  return sudh

# %%
test12(1,2,34,4)
# Out:
# (1, 2, 34, 4)

# %%
def test13(*args, a):
  return args,a

# %%
test13(1,2,3,4,a=23)
# Out:
# ((1, 2, 3, 4), 23)

# %%
def test14(c,d,a=23,b=1):
  return a,b,c,d

# %%
test14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
test14(2,5,a=2342)
# Out:
# (2342, 1, 2, 5)

# %%
def test15(**kwargs):

 return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a=[1,2,3,4],b="sudh",c=23.45)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'sudh', 'c': 23.45}

# %%
def add(a,b):
  return a+b

# %%
def calc(a,b,operator):
  if(input :+):
    print(a+b)
