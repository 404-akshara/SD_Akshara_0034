# %%
def calc(a,b,p):

 if(p=="+"):
   print(a+b)
 elif(p=="-"):
   print(a-b)
 elif(p=="*"):
   print(a*b)
 elif(p=="/"):
   print(a/b)
 return"done"
n1=int(input("enter first number"))
n2=int(input("enter second number"))
p=input("enter operator")
calc(n1,n2,p )
# Out:
# enter first number12
# enter second number10
# enter operator+
# 22
# 'done'

# %%
pin=int(input("Enter your pin:"))
if pin==1234:
    print("correct pin")
else:
   print("incorrect pin")

q=input(print("to avail SERVICES press y/n"))
if q=="y":
  print("WELCOME TO THE ATM CHOOSE from below")
  print("  1.)cash withdraw")
  print("  2.)check amount")
  print("  3.)cash or cheque deposit")
  print("  4.)transfer funds")
  print("  5.)pay bills")
  s=int(input("enter your choice"))
  if(s==1):
    print("enter the amount u want to withdraw")
  elif(s==2):
    print("12000")
  elif(s==3):
    a=input(print("enter the amount u want to deposit"))
  elif(s==4):
    b=int(input("enter the amount u want to transfer"))
  elif(s==5):
    c=int(input("enter the amount u want to pay"))
  else:
    print("invalid choice")
elif q=="n":
   print("thank you")
# Out:
# Enter your pin:1234
# correct pin
# to avail SERVICES press y/n
# Noney
# WELCOME TO THE ATM CHOOSE from below
#   1.)cash withdraw
#   2.)check amount
#   3.)cash or cheque deposit
#   4.)transfer funds
#   5.)pay bills
# enter your choice5
# enter the amount u want to pay20000
