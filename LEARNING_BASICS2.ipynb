# %%
l=[1,345,45,"sudh",True,5+7j,345.456]

# %%
l.append(3)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 3]

# %%
l.pop()
# Out:
# 3

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
l.insert(3,"ANSHITA")

# %%
l
# Out:
# [1, 345, 45, 'ANSHITA', 'sudh', True, (5+7j), 345.456]

# %%
t=(2,3,4,5,'sudh',45.56,False,(45+457j),[3,4,5])

# %%
type(t)
# Out:
# tuple

# %%
len(t) #PRINTS THE LENGTH OF TUPLE
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1] #REVERSE INDEX NUMBER TEST
# Out:
# [3, 4, 5]

# %%
s1={} #SET

# %%
type(s1)
# Out:
# dict

# %%
s2={2,3,4,55,6}

# %%
type(s2)
# Out:
# set

# %%
s3={324,456,456,"SUDH",45+45j,34.465,(3,4,5)}

# %%
s3
# Out:
# {(3, 4, 5), (45+45j), 324, 34.465, 456, 'SUDH'}

# %%
s4={2,3,4,5,62,3,2,3,3,4,"SUDH","SUDH"} #SET DO NOT ALLOW REPETITION OF ELEMENTS

# %%
l2=[2,3,4,5,62,3,2,3,3,4,"SUDH","SUDH"]

# %%
l2
# Out:
# [2, 3, 4, 5, 62, 3, 2, 3, 3, 4, 'SUDH', 'SUDH']

# %%
s4
# Out:
# {2, 3, 4, 5, 62, 'SUDH'}

# %%
s5={234,45,23,12,567,45,5,789,2234,"ABC",456,342,23}

# %%
s4
# Out:
# {2, 3, 4, 5, 62, 'SUDH'}

# %%
s4.add("PARI")  #TO ADD ELEMENT IN SET

# %%
s4
# Out:
# {2, 3, 4, 5, 62, 'PARI', 'SUDH'}

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d1={'KEY':'SUDH'}

# %%
d2={'NAME':'SUDHANSHU','EMAIL':'sg@gmail.com',"NUMBER":13458558}

# %%
d3={234:'SUDH','_WER':"KUMAR",True:24234}

# %%
d3[234]
# Out:
# 'SUDH'

# %%
d3[1]
# Out:
# 24234
