# %%
a=1

# %%
b=3.14

# %%
c='c'

# %%
d="hamster"

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
num=[1,345.45,"sudh",True,5+7j,345.456]

# %%
num[4].real
# Out:
# 5.0

# %%
num[0:3:1]
# Out:
# [1, 345.45, 'sudh']

# %%
num[0:5:4]
# Out:
# [1, (5+7j)]

# %%
num[-1]
# Out:
# 345.456

# %%
num[-1:-5:2]
# Out:
# []

# %%
num[-1:-5:-2]
# Out:
# [345.456, True]

# %%
num[1:6:-2]
# Out:
# []

# %%
num[1:6:2]
# Out:
# [345.45, True, 345.456]

# %%
num.append(1)

# %%
num
# Out:
# [1, 345.45, 'sudh', True, (5+7j), 345.456, 1, 1]

# %%
num.pop()
# Out:
# 1

# %%
s="i am fucking dead"

# %%
num+list(s)
# Out:
# [1,
#  345.45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  'i',
#  ' ',
#  'a',
#  'm',
#  ' ',
#  'f',
#  'u',
#  'c',
#  'k',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'd',
#  'e',
#  'a',
#  'd']

# %%
l1=[12,31.5,"anshi",True]

# %%
l1.append(65)

# %%
l1
# Out:
# [12, 31.5, 'anshi', True, 65]

# %%
l1.pop()
# Out:
# 65

# %%
l1
# Out:
# [12, 31.5, 'anshi', True]

# %%
num[2][0]
# Out:
# 's'

# %%
num[2][0:2:1]
# Out:
# 'su'

# %%
str(num[3])[0:2]
# Out:
# 'Tr'

# %%
num.insert(4,'45')

# %%
num
# Out:
# [1, 345.45, 'sudh', True, '45', (5+7j), 345.456]

# %%
name=input("Enter your name: ")
# Out:
# Enter your name: AKSHARA

# %%
age=int(input("Enter your age:"))
# Out:
# Enter your age:19

# %%
x=(1,2,3)
y=list(x)
print(y)
# Out:
# [1, 2, 3]

# %%
q=[1,2,3]
l=tuple(q)
print(l)
# Out:
# (1, 2, 3)

# %%
w="10"
t=int(w)
print(t);
# Out:
# 10

# %%
d="3.14"
e=float(d);
print (e)
# Out:
# 3.14

# %%
u=29
v=str(u)
print (v)
# Out:
# 29

# %%
l1=[3,4,5]
