# %%
l=[5,9,6,7,8,9,2,3,18,19]

# %%
sum=0
for i in l:
  sum=sum+i

# %%
sum
# Out:
# 86

# %%
s=0
for i in l:
  if l.index(i)%2==0:
   s=s+i;

# %%
s
# Out:
# 39

# %%
d={'A':65,'B':66,'C':67,'D':68,'E':69}
keys=[]
values=[]
for items in d.items():

  keys.append(items[0])
  values.append(items[1])

print(keys)
print(values)
# Out:
# ['A', 'B', 'C', 'D', 'E']
# [65, 66, 67, 68, 69]
