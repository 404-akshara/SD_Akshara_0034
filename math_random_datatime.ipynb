# %%
import math

num=25
print(math.sqrt(num))
# Out:
# 5.0

# %%
import math
print(math.pow(2,5))
# Out:
# 32.0

# %%
import math
print(math.factorial(5))
# Out:
# 120

# %%
import math
print(math.floor(4,9))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1097/2320898242.py in <cell line: 0>()
#       1 import math
# ----> 2 print(math.floor(4,9))
#
# TypeError: math.floor() takes exactly one argument (2 given)

# %%
print(abs(-50))

# %%
print(math.gcd(24,36))
# Out:
# 12

# %%
import math
print(math.lcm(12,18))
# Out:
# 36

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
print(math.sin(math.radians(90)))
# Out:
# 1.0

# %%
print(math.tan(math.radians(45)))
# Out:
# 0.9999999999999999

# %%
print(math.log10(100))
# Out:
# 2.0

# %%
print(math.log(100))
# Out:
# 4.605170185988092

# %%
import random
print(random.random())
# Out:
# 0.2330208693077862

# %%
import random
print(random.randrange(1,100))
# Out:
# 37

# %%
import random
fruits=["apple","banana","mango","orange"]
print(random.choice(fruits))
# Out:
# mango

# %%
import random
numbers=[1,2,3,4,5]
random.shuffle(numbers)
print(numbers)
# Out:
# [2, 4, 3, 5, 1]

# %%
import random
print(random.uniform(1,10))
# Out:
# 9.350238850347228

# %%
import random
print(random.choice([True,False]))
# Out:
# False

# %%
import random
otp=random.randint(1000,9999)
print("OTP=",otp)
# Out:
# OTP= 2810

# %%
import datetime

# %%
print(datetime.datetime.now().time())
# Out:
# 04:11:28.144502

# %%
import datetime
print(datetime.datetime.now().year)
# Out:
# 2026

# %%
import datetime
print(datetime.datetime.now().day)
# Out:
# 21

# %%
import datetime
print(datetime.datetime.now().second)
# Out:
# 28

# %%
#custom
d=datetime.date(2026,7,19)

# %%
import datetime
t=datetime.time(10,30,45)

# %%
import datetime
date1 = datetime.date(2026,7,19)
date2 = datetime.date(2026,8,19)

# %%
import datetime
today = datetime.datetime.now()
print(today.strftime("%B"))
# Out:
# July

# %%
import time
from IPython.display import clear_output
from datetime import datetime

while True:
  clear_output(wait=True)

  current_time = datetime.now().strftime("%I:%M:%S %p")

  print(datetime.datetime.now().day)
  print(current_time)

  time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1097/503890246.py in <cell line: 0>()
#       8   current_time = datetime.now().strftime("%I:%M:%S %p")
#       9
# ---> 10   print(datetime.datetime.now().day)
#      11   print(current_time)
#      12
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'
